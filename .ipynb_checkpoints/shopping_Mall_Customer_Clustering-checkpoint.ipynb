# %%
import numpy as np
import pandas as pd
from pandas import plotting

# For Visualization
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight') # For better View

import plotly.offline as py
from plotly.offline import init_notebook_mode, iplot
import plotly.graph_objs as go
from plotly import tools
init_notebook_mode(connected = True)
import plotly.figure_factory as ff

# for path
import os
print(os.listdir("./data"))
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ['911.csv', 'auction.csv', 'Mall_Customers.csv', 'pokemon_data.txt', 'pokemon_data.xlsx', 'super_store.csv', 'swarovski.csv']

# %%
#os.getcwd()
#os.listdir(str(os.getcwd()))

# %% [markdown]
# ### Loading the data

# %%
df  = pd.read_csv("data/Mall_Customers.csv")

# %%
df.shape
# Out:
# (200, 5)

# %%
df.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
data = ff.create_table(df.describe())
py.iplot(data)
# Out:
# <div>
#
#
#             <div id="1e2a34e9-d9c5-4bb7-afb9-54ab0bbc9b3b" class="plotly-graph-div" style="height:320px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1e2a34e9-d9c5-4bb7-afb9-54ab0bbc9b3b")) {
#                     Plotly.newPlot(
#                         '1e2a34e9-d9c5-4bb7-afb9-54ab0bbc9b3b',
#                         [{"colorscale": [[0, "#00083e"], [0.5, "#ededee"], [1, "#ffffff"]], "hoverinfo": "none", "opacity": 0.75, "showscale": false, "type": "heatmap", "z": [[0, 0, 0, 0], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1]]}],
# ...

# %% [markdown]
# ### describing the data

# %%
desc = ff.create_table(df.describe())
py.iplot(desc)
# Out:
# <div>
#
#
#             <div id="f67fc477-e6e7-47fb-ad37-ccd658c2927e" class="plotly-graph-div" style="height:320px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f67fc477-e6e7-47fb-ad37-ccd658c2927e")) {
#                     Plotly.newPlot(
#                         'f67fc477-e6e7-47fb-ad37-ccd658c2927e',
#                         [{"colorscale": [[0, "#00083e"], [0.5, "#ededee"], [1, "#ffffff"]], "hoverinfo": "none", "opacity": 0.75, "showscale": false, "type": "heatmap", "z": [[0, 0, 0, 0], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1]]}],
# ...

# %%
plt.rcParams["figure.figsize"]= (15,10)
plotting.andrews_curves(df.drop("CustomerID", axis=1),"Gender")
plt.title("Andrew Curves for Gender")
plt.show()

# %%
from warnings import filterwarnings
filterwarnings("ignore")

plt.rcParams["figure.figsize"]=(18,8)

plt.subplot(1,2,1)
sns.set(style="ticks")
sns.distplot(df["Annual Income (k$)"])
plt.title("Distribution of Annual Income", fontsize =20)
plt.xlabel("Range of Annual Income")
plt.ylabel("Count")

plt.subplot(1,2,2)
sns.set(style="dark")
sns.distplot(df["Age"],color ="red")

plt.title("Distribution of Age",fontsize=20)
plt.xlabel("Distribution of Age")
plt.ylabel("Count")

plt.show()

# %% [markdown]
# In the above fig we can see Annual Income is less than 80 overall and distribution of Age who visi store are 30 35 are high

# %%
labels = ["Female","Male"]
size = df["Gender"].value_counts()
size
# Out:
# Female    112
# Male       88
# Name: Gender, dtype: int64

# %%
colors = ["lightgreen", "orange"]
plt.figure(figsize=[10,5])
#plt.rcParams['figure.figsize'] = (10, 8)
plt.pie(size,colors = colors,labels=labels,shadow=True , autopct="%.8f%%")
plt.title("Gender", fontsize =20)
plt.axis("off")
plt.legend()
plt.show()

# %% [markdown]
# The above Pie diagram show us the distribution of the Gender i.e. male and female .and also the figure clearly showing the females are regular customer.

# %%
sns.countplot(df.Age,palette = "rainbow",order=df.Age.value_counts().index)
plt.title("Distribution of Annual Income")
plt.xlabel("Age")
plt.ylabel("Counted")
plt.show()

# %% [markdown]
# We can see age of 32 are regular and and age more than 50/55 are very rare

# %%
sns.countplot(df["Annual Income (k$)"],palette="rainbow")
plt.show()

# %% [markdown]
# We cant make any decision from above figure. We only can see the range beet ween 15 to 100.. income range but making decision is very hard

# %%
sns.countplot(df["Spending Score (1-100)"],
             facecolor ="gold",
             linewidth =5,
             edgecolor =sns.color_palette("dark",3))

plt.show()

# %%
sns.pairplot(df,palette="hus1",kind="reg")
plt.title("Pairplot for the Data",  fontsize = 20)
plt.show()

# %%
sns.heatmap(df.corr(), cmap = "Accent", annot = True)
plt.title("Heatmap for the Data")
plt.show()

# %% [markdown]
# Heat map is the best way to see correlation of different variable
# How ever we cant see any good co relation among the data

# %% [markdown]
# ### Gender Vs Spendscore

# %%
sns.boxenplot(df["Gender"],df["Spending Score (1-100)"],palette ="Blues")
plt.show()

# %%
sns.violinplot(df.Gender,df["Annual Income (k$)"])
plt.title("Gender Vs Spending Score")
plt.show()

# %% [markdown]
# In the above diagram we can see that the male earn more than female but low income is almost same

# %%
sns.stripplot(df.Gender,df.Age,palette= "Purples", size = 10)
plt.show()

# %%
sns.lineplot(df["Annual Income (k$)"],df["Age"],color = "red")
sns.lineplot(df["Annual Income (k$)"],df["Spending Score (1-100)"])
plt.show()

# %% [markdown]
# The above Plot Between Annual Income and Age represented by a blue color line and a plot between Annual Income and the Spending Score represented by a pink color. shows how Age and Spending Varies with Annual Income

# %% [markdown]
# ## Clustering Analysis

# %%
x = df.iloc[:,[3,4]].values   # 3 and 4 colums from the original table
x.shape
# Out:
# (200, 2)

# %% [markdown]
# ## K-Means Algorithm

# %%
from sklearn.cluster import KMeans
wcss = []

for i in range(1,11):
    km  = KMeans(n_clusters=i,init = "k-means++",max_iter = 300, n_init = 10, random_state=0)
    km.fit(x)
    wcss.append(km.inertia_)
plt.plot(range(1,11),wcss)
plt.title("The Elbow Method")
plt.xlabel("No. of Clusters")
plt.ylabel("wcss")
plt.show()

# %% [markdown]
# ## Visualizaing the Clusters

# %%
km = KMeans(n_clusters =5 , init = "k-means++",max_iter = 300 , n_init = 10, random_state=0)
y_means = km.fit_predict(x)

plt.scatter(x[y_means ==0,0],x[y_means==0,1],s = 100 , c ="pink", label = "miser")
plt.scatter(x[y_means ==1,0],x[y_means ==1,1], s = 100, c ="yellow", label= "general")
plt.scatter(x[y_means == 2,0],x[y_means ==2,1], s =100,c ="cyan", label = "target")
plt.scatter(x[y_means==4,0],x[y_means ==4,1],s=100, c = "orange", label = "careful")

plt.scatter(km.cluster_centers_[:,0], km.cluster_centers_[:,1],s=50 , c="blue", label= "centeroid")
plt.style.use("fivethirtyeight")
plt.title("K Means Clustering")
plt.xlabel("Annual Income")
plt.ylabel("Spending Score")
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# This Clustering Analysis gives us a vey clear insight about the different segment segments of the customers in the Mall. There are clearly Five segments of Customers namely Miser, General, Target, Spendthrift, Careful based on their Annual Income and Spending Score which are reportedly the best factors/ attributes to determine the segments of customer in a Mall

# %% [markdown]
# ## Hierarchial Clustering

# %% [markdown]
# also hierarchical cluster analysis, is an algorithm that groups similar objects into groups calledc clusters. The endpoint is a set of clusters, where each cluster is distinct from each other cluster and the objects within each cluster are broadly similar to each other.

# %%
# Using Dendrograms to find the no. of Optimal Clusters 
import scipy.cluster.hierarchy as sch
dendrogram = sch.dendrogram(sch.linkage(x,method="ward"))
plt.title("Dendrogam")
plt.ylabel("Educational Distance ")
plt.show()

# %%
# Visualizing the Clusters of Hierarchial Clustering
from sklearn.cluster import AgglomerativeClustering
hc = AgglomerativeClustering(n_clusters = 5 , affinity= "euclidean", linkage ="ward")
y_hc = hc.fit_predict(x)

plt.scatter(x[y_hc ==0,0])
