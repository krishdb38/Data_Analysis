# %%
import pandas as pd
import numpy as np

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 5C38-E82B
#
#  Directory of C:\Users\krish\Desktop\Git Hub\Data_Analysis\Pandas-Cookbook-master
#
# 12/23/2019  10:24 PM    <DIR>          .
# 12/23/2019  10:24 PM    <DIR>          ..
# 12/23/2019  10:15 PM    <DIR>          .ipynb_checkpoints
# 12/23/2019  10:13 PM    <DIR>          Pandas-Cookbook-master
# 12/23/2019  10:24 PM             8,818 practice_1.ipynb
#                1 File(s)          8,818 bytes
#                4 Dir(s)  75,181,780,992 bytes free

# %%
movie = pd.read_csv("Pandas-Cookbook-master\data\movie.csv")

# %%
movie.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
movie.index
# Out:
# RangeIndex(start=0, stop=4916, step=1)

# %%
data = movie.values

# %%
type(data)
# Out:
# numpy.ndarray

# %%
data.shape,movie.shape,type(data),type(movie)
# Out:
# ((4916, 28), (4916, 28), numpy.ndarray, pandas.core.frame.DataFrame)

# %%
movie.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %%
movie.get_dtype_counts() #Count the total Numbers of Col data Type
# Out:
# float64    13
# int64       3
# object     12
# dtype: int64

# %%
movie.director_name
#pd.reset_option("^display")
# Out:
# 0            James Cameron
# 1           Gore Verbinski
# 2               Sam Mendes
# 3        Christopher Nolan
# 4              Doug Walker
# 5           Andrew Stanton
# 6                Sam Raimi
# 7             Nathan Greno
# 8              Joss Whedon
# 9              David Yates
# 10             Zack Snyder
# 11            Bryan Singer
# 12            Marc Forster
# 13          Gore Verbinski
# 14          Gore Verbinski
# 15             Zack Snyder
# 16          Andrew Adamson
# 17             Joss Whedon
# 18            Rob Marshall
# 19        Barry Sonnenfeld
# 20           Peter Jackson
# 21               Marc Webb
# 22            Ridley Scott
# 23           Peter Jackson
# 24             Chris Weitz
# 25           Peter Jackson
# 26           James Cameron
# 27           Anthony Russo
# 28              Peter Berg
# 29         Colin Trevorrow
#                ...
# 4886            Eric Eason
# 4887              Uwe Boll
# 4888     Richard Linklater
# ...

# %%
director = movie.director_name
type(director)
# Out:
# pandas.core.series.Series

# %%
#director.to_frame()
#director

# %%
director.shape,director.size, director.count() #Count will remove NAN value
# Out:
# ((4916,), 4916, 4814)

# %%
director.describe()
# Out:
# count                 4814
# unique                2397
# top       Steven Spielberg
# freq                    26
# Name: director_name, dtype: object

# %%
director.isnull().sum(),director.isnull().count() , director.shape
# Out:
# (102, 4916, (4916,))

# %%
director.value_counts(normalize=False) #True
director.hasnans
director.notna
director.notnull()
5
# Out:
# 5

# %%
imdb_score = movie["imdb_score"]

# %%
imdb_score.head()
# Out:
# 0    7.9
# 1    7.1
# 2    6.8
# 3    8.5
# 4    7.1
# Name: imdb_score, dtype: float64

# %%
(imdb_score+1).head() # Add One to all
# Out:
# 0    8.9
# 1    8.1
# 2    7.8
# 3    9.5
# 4    8.1
# Name: imdb_score, dtype: float64

# %%
(imdb_score*2).head() #Multiply 2 in All row
# Out:
# 0    15.8
# 1    14.2
# 2    13.6
# 3    17.0
# 4    14.2
# Name: imdb_score, dtype: float64

# %%
(imdb_score>7).head()
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# Name: imdb_score, dtype: bool

# %%
director = movie.director_name

# %%
imdb_score[director == "James Cameron"] #
# Out:
# 0       7.9
# 26      7.7
# 285     8.5
# 288     7.2
# 599     7.6
# 2455    8.4
# 3508    8.1
# Name: imdb_score, dtype: float64

# %%
imdb_score.add(1).head() #mul() , floordiv()  , gt()  , eq ("James Cameron") = director == "James Cameron"
# Out:
# 0    8.9
# 1    8.1
# 2    7.8
# 3    9.5
# 4    8.1
# Name: imdb_score, dtype: float64

# %%
movie.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
actor_1_fb_likes = movie["actor_1_facebook_likes"]
director = movie.director_name

# %%
actor_1_fb_likes.dtype
# Out:
# dtype('float64')

# %%
actor_1_fb_likes.fillna("0")\
.astype(int)\
.head()
# Out:
# 0     1000
# 1    40000
# 2    11000
# 3    27000
# 4      131
# Name: actor_1_facebook_likes, dtype: int32

# %%
movie.index
# Out:
# RangeIndex(start=0, stop=4916, step=1)

# %%
col = ['color', 'director_name', 'num_critic_for_reviews']
movie[col].head()
movie.get_dtype_counts()
# Out:
# float64    13
# int64       3
# object     12
# dtype: int64

# %%
movie.select_dtypes(include=["float"]).head()
# Out:
#    num_critic_for_reviews  duration  director_facebook_likes  \
# 0                   723.0     178.0                      0.0
# 1                   302.0     169.0                    563.0
# 2                   602.0     148.0                      0.0
# 3                   813.0     164.0                  22000.0
# 4                     NaN       NaN                    131.0
#
#    actor_3_facebook_likes  actor_1_facebook_likes        gross  \
# 0                   855.0                  1000.0  760505847.0
# 1                  1000.0                 40000.0  309404152.0
# 2                   161.0                 11000.0  200074175.0
# 3                 23000.0                 27000.0  448130642.0
# 4                     NaN                   131.0          NaN
#
#    facenumber_in_poster  num_user_for_reviews       budget  title_year  \
# 0                   0.0                3054.0  237000000.0      2009.0
# 1                   0.0                1238.0  300000000.0      2007.0
# ...

# %%
movie.filter(like="actor").head()  #
# Out:
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  \
# 0                   855.0  Joel David Moore                  1000.0
# 1                  1000.0     Orlando Bloom                 40000.0
# 2                   161.0      Rory Kinnear                 11000.0
# 3                 23000.0    Christian Bale                 27000.0
# 4                     NaN        Rob Walker                   131.0
#
#       actor_1_name          actor_3_name  actor_2_facebook_likes
# 0      CCH Pounder             Wes Studi                   936.0
# 1      Johnny Depp        Jack Davenport                  5000.0
# 2  Christoph Waltz      Stephanie Sigman                   393.0
# 3        Tom Hardy  Joseph Gordon-Levitt                 23000.0
# 4      Doug Walker                   NaN                    12.0

# %%
movie.filter(regex='actor').head()
# Out:
#    actor_3_facebook_likes      actor_2_name  actor_1_facebook_likes  \
# 0                   855.0  Joel David Moore                  1000.0
# 1                  1000.0     Orlando Bloom                 40000.0
# 2                   161.0      Rory Kinnear                 11000.0
# 3                 23000.0    Christian Bale                 27000.0
# 4                     NaN        Rob Walker                   131.0
#
#       actor_1_name          actor_3_name  actor_2_facebook_likes
# 0      CCH Pounder             Wes Studi                   936.0
# 1      Johnny Depp        Jack Davenport                  5000.0
# 2  Christoph Waltz      Stephanie Sigman                   393.0
# 3        Tom Hardy  Joseph Gordon-Levitt                 23000.0
# 4      Doug Walker                   NaN                    12.0

# %%
movie.ndim, len(movie), movie.shape
# Out:
# (2, 4916, (4916, 28))

# %%
movie.count().head()
# Out:
# color                      4897
# director_name              4814
# num_critic_for_reviews     4867
# duration                   4901
# director_facebook_likes    4814
# dtype: int64

# %%
movie.min()
# Out:
# num_critic_for_reviews          1.00
# duration                        7.00
# director_facebook_likes         0.00
# actor_3_facebook_likes          0.00
# actor_1_facebook_likes          0.00
# gross                         162.00
# num_voted_users                 5.00
# cast_total_facebook_likes       0.00
# facenumber_in_poster            0.00
# num_user_for_reviews            1.00
# budget                        218.00
# title_year                   1916.00
# actor_2_facebook_likes          0.00
# imdb_score                      1.60
# aspect_ratio                    1.18
# movie_facebook_likes            0.00
# dtype: float64

# %%
movie.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4867.000000  4901.000000              4814.000000
# mean               137.988905   107.090798               691.014541
# std                120.239379    25.286015              2832.954125
# min                  1.000000     7.000000                 0.000000
# 25%                 49.000000    93.000000                 7.000000
# 50%                108.000000   103.000000                48.000000
# 75%                191.000000   118.000000               189.750000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             4893.000000             4909.000000  4.054000e+03
# mean               631.276313             6494.488491  4.764451e+07
# std               1625.874802            15106.986884  6.737255e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %%
movie.describe(percentiles=[0.1,0.3,0.6,0.7,0.9])
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4867.000000  4901.000000              4814.000000
# mean               137.988905   107.090798               691.014541
# std                120.239379    25.286015              2832.954125
# min                  1.000000     7.000000                 0.000000
# 10%                 17.000000    86.000000                 0.000000
# 30%                 60.000000    95.000000                11.000000
# 50%                108.000000   103.000000                48.000000
# 60%                137.000000   108.000000                83.800000
# 70%                169.000000   114.000000               149.100000
# 90%                294.000000   134.000000               545.000000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             4893.000000             4909.000000  4.054000e+03
# ...

# %%
movie.isnull().head()
# Out:
#    color  director_name  num_critic_for_reviews  duration  \
# 0  False          False                   False     False
# 1  False          False                   False     False
# 2  False          False                   False     False
# 3  False          False                   False     False
# 4   True          False                    True      True
#
#    director_facebook_likes  actor_3_facebook_likes  actor_2_name  \
# 0                    False                   False         False
# 1                    False                   False         False
# 2                    False                   False         False
# 3                    False                   False         False
# 4                    False                    True         False
#
#    actor_1_facebook_likes  gross  genres  ...  num_user_for_reviews  language  \
# 0                   False  False   False  ...                 False     False
# ...

# %%
movie.min(skipna = True).head()  #False or True
# Out:
# num_critic_for_reviews     1.0
# duration                   7.0
# director_facebook_likes    0.0
# actor_3_facebook_likes     0.0
# actor_1_facebook_likes     0.0
# dtype: float64

# %%
movie.isnull().sum().head()
# Out:
# color                       19
# director_name              102
# num_critic_for_reviews      49
# duration                    15
# director_facebook_likes    102
# dtype: int64

# %%
movie.isnull().sum().sum() #Total Numbers of null in data
# Out:
# 2654

# %%
movie.isnull().get_dtype_counts()
# Out:
# bool    28
# dtype: int64

# %%
college = pd.read_csv("Pandas-Cookbook-master\data\college.csv")

# %%
college_ugds = pd.read_csv("Pandas-Cookbook-master/data/college.csv")

# %%
college_ugds.head()
# Out:
#                                 INSTNM        CITY STABBR  HBCU  MENONLY  \
# 0             Alabama A & M University      Normal     AL   1.0      0.0
# 1  University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# 2                   Amridge University  Montgomery     AL   0.0      0.0
# 3  University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# 4             Alabama State University  Montgomery     AL   1.0      0.0
#
#    WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 0        0.0         0     424.0     420.0           0.0  ...     0.0000
# 1        0.0         0     570.0     565.0           0.0  ...     0.0368
# 2        0.0         1       NaN       NaN           1.0  ...     0.0000
# 3        0.0         0     595.0     590.0           0.0  ...     0.0172
# 4        0.0         0     425.0     430.0           0.0  ...     0.0098
#
#    UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# ...

# %%
college[college_ugds==0].dropna()
# Out:
# Empty DataFrame
# Columns: [INSTNM, CITY, STABBR, HBCU, MENONLY, WOMENONLY, RELAFFIL, SATVRMID, SATMTMID, DISTANCEONLY, UGDS, UGDS_WHITE, UGDS_BLACK, UGDS_HISP, UGDS_ASIAN, UGDS_AIAN, UGDS_NHPI, UGDS_2MOR, UGDS_NRA, UGDS_UNKN, PPTUG_EF, CURROPER, PCTPELL, PCTFLOAN, UG25ABV, MD_EARN_WNE_P10, GRAD_DEBT_MDN_SUPP]
# Index: []
#
# [0 rows x 27 columns]

# %%
college_compare = college == college_ugds

# %%
college_compare.head(2)
# Out:
#    INSTNM  CITY  STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  SATVRMID  \
# 0    True  True    True  True     True       True      True      True
# 1    True  True    True  True     True       True      True      True
#
#    SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  \
# 0      True          True  ...       True      True       True      True
# 1      True          True  ...       True      True       True      True
#
#    CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 0      True     True      True     True             True                True
# 1      True     True      True     True             True                True
#
# [2 rows x 27 columns]

# %%
college_ugds.isnull()\
.sum(axis=1)\
.sort_values(ascending=False)\
.head()
# Out:
# 7239    22
# 7534    21
# 7227    21
# 7237    21
# 7273    21
# dtype: int64

# %%
college.loc[[4,4,4]]
# Out:
#                      INSTNM        CITY STABBR  HBCU  MENONLY  WOMENONLY  \
# 4  Alabama State University  Montgomery     AL   1.0      0.0        0.0
# 4  Alabama State University  Montgomery     AL   1.0      0.0        0.0
# 4  Alabama State University  Montgomery     AL   1.0      0.0        0.0
#
#    RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  UGDS_NRA  \
# 4         0     425.0     430.0           0.0  ...     0.0098    0.0243
# 4         0     425.0     430.0           0.0  ...     0.0098    0.0243
# 4         0     425.0     430.0           0.0  ...     0.0098    0.0243
#
#    UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# 4     0.0137    0.0892         1   0.7347    0.7554    0.127            26600
# 4     0.0137    0.0892         1   0.7347    0.7554    0.127            26600
# 4     0.0137    0.0892         1   0.7347    0.7554    0.127            26600
#
#    GRAD_DEBT_MDN_SUPP
# 4             33118.5
# ...

# %%
college.describe(include=[np.object,pd.Categorical]).T
# Out:
#                    count unique                 top  freq
# INSTNM              7535   7535  CET-San Bernardino     1
# CITY                7535   2514            New York    87
# STABBR              7535     59                  CA   773
# MD_EARN_WNE_P10     6413    598   PrivacySuppressed   822
# GRAD_DEBT_MDN_SUPP  7503   2038   PrivacySuppressed  1510
